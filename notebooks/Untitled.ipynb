# %%
import pandas as pd

# %%
channel_ids = ['100064855413897',
                '100075906194023',
                '100083471904258',
                '101749399223843',
                '102025789001782',
                '104654224376652',
                '105070052500731',
                '105213518938574',
                '105795978594639',
                '107514801735175',
                '107672500789766',
                '1086451581439050',
                '110121977606685',
                '114253530285006',
                '1159932557403140',
                '117024167982748',
                '118883634811868',
                '120304925392790',
                '123790041031678',
                '127439507270196',
                '128425230530002',
                '1374613519460637',
                '142577507712',
                '149887627901',
                '154344434967',
                '1554974721401650',
                '1588539511437723',
                '169383494938',
                '176339122382143',
                '1910244149266506',
                '201021766701758',
                '201337313337245',
                '238749349516480',
                '260212261199',
                '260600001420798',
                '274432779381675',
                '283348121682053',
                '286567251709437',
                '294029974405480',
                '294662213128',
                '295830058648',
                '303522857815',
                '303765603054826',
                '315608322192114',
                '34342703216',
                '352138955102',
                '371509533894',
                '380457289451270',
                '482434785121894',
                '519260718174772',
                '555751707830060',
                '566360780125137',
                '581450158658653',
                '595852567193299',
                '614409738678958',
                '651188731584691',
                '679928748809066',
                '680592732061947',
                '871006636270529',
                '927058587374254',
                '929399697073756']

# %%
df = pd.read_csv(f"../data/raw/FBE/GAM2026_FBE_engagements_redshift_extract.csv")
df[df['page_id'].isin(channel_ids)]
# Out:
# Empty DataFrame
# Columns: [week_commencing, page_id, engaged_reach]
# Index: []
